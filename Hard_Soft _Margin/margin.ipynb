# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs

X,y=make_blobs(n_samples=100,centers=2, random_state=42, cluster_std=1.0)
y=np.where(y == 0, -1 , 1)
#Convert labels from {0,1} to {-1,1}
plt.scatter(X[:,0],X[:,1],c=y,cmap='bwr')
plt.title("Linearly seperable data")
plt.show()

# %%
from sklearn.svm import SVC
svm_hard = SVC(kernel='linear',C=1e6)
svm_hard.fit(X,y)
print("Number of support vectors:",len(svm_hard.support_vectors_))

w=svm_hard.coef_[0]
b=svm_hard.intercept_[0]

print("w: ",w)
print("b: ",b)
# Out:
# Number of support vectors: 2
# w:  [ 0.24748994 -0.17407192]
# b:  0.7341550476191021

# %%
plt.figure(figsize=(7,6))
 
# Plot data points
plt.scatter(X[:, 0], X[:, 1], c=y, cmap='bwr', edgecolors='k')
 
# Highlight support vectors
plt.scatter(
    svm_hard.support_vectors_[:,0],
    svm_hard.support_vectors_[:,1],
    s=120, facecolors='none', edgecolors='k', linewidth=2,
    label='Support Vectors'
)
 
# Create X values for line plotting
x_vals = np.linspace(X[:,0].min()-1, X[:,0].max()+1, 200)
 
# Decision boundary: w.x + b = 0
y_decision = -(w[0] * x_vals + b) / w[1]
 
# Margin boundaries: w.x + b = +-1
y_margin_pos = -(w[0] * x_vals + b - 1) / w[1]
y_margin_neg = -(w[0] * x_vals + b +1 ) / w[1]
 
# Plot lines
plt.plot(x_vals, y_decision, 'k-', label = "Decision Boundary")
plt.plot(x_vals, y_margin_pos, 'k--', label = "Margin +1")
plt.plot(x_vals, y_margin_neg, 'k--', label = "Margin -1")
 
# Shade margin area
plt.fill_between(
    x_vals, y_margin_pos, y_margin_neg,
    color='gray', alpha=0.2, label = "Margin Area"
)
 
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.title("Hard Margin SVM with Margin Visualization")
plt.legend()
plt.show()

# %%
X_overlap, y_overlap = make_blobs(n_samples=100, centers=2, random_state=42, cluster_std=3)
y_overlap=np.where(y_overlap==0,-1,1)
 
plt.scatter(X_overlap[:,0], X_overlap[:,1], c=y_overlap, cmap="bwr")
plt.title("Overlapping data")
plt.show()

# %%
from sklearn.svm import SVC
#Hard margin SVM(Very large C)
svm_hard=SVC(kernel='linear',C=1e6)
svm_hard.fit(X_overlap,y_overlap)

print("Number of support vecrorts:", len(svm_hard.support_vectors_))
# Out:
# Number of support vecrorts: 3

# %%
w=svm_hard.coef_[0] #Weight vector
b=svm_hard.intercept_[0] #Bias

# %%
w=svm_hard.coef_[0] 
b=svm_hard.intercept_[0] 

plt.figure(figsize=(7,6))
plt.scatter(X_overlap[:,0],X_overlap[:,1],c=y_overlap,cmap='bwr',edgecolors='k')

#Support Vectors
plt.scatter(
    svm_hard.support_vectors_[:,0],
    svm_hard.support_vectors_[:,1],
    s=120, facecolors='none', edgecolors='k', linewidth=2,
    label='Support Vectors'
)

#Decision boundry
x_vals=np.linspace(
    X_overlap[:,0].min()-1,
    X_overlap[:,0].max()+1,
    200
)

y_decision = -(w[0] * x_vals + b) / w[1]
y_margin_pos = -(w[0] * x_vals + b - 1) / w[1]
y_margin_neg = -(w[0] * x_vals + b +1 ) / w[1]

plt.plot(x_vals, y_decision, 'k-', label = "Decision Boundary")
plt.plot(x_vals, y_margin_pos, 'k--', label = "Margin +1")
plt.plot(x_vals, y_margin_neg, 'k--', label = "Margin -1")
 
# Shade margin area
plt.fill_between(
    x_vals, y_margin_pos, y_margin_neg,
    color='gray', alpha=0.2, label = "Margin Area"
)
 
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.title("Hard Margin SVM with Margin Visualization")
plt.legend()
plt.show()

# %%
from sklearn .svm import SVC

svm_soft=SVC(kernel='linear',C=1.0)
svm_soft.fit(X_overlap,y_overlap)

print("Number of support vectors:", len(svm_soft.support_vectors_))
# Out:
# Number of support vectors: 6

# %%
w=svm_soft.coef_[0] 
b=svm_soft.intercept_[0] 

plt.figure(figsize=(7,6))
plt.scatter(X_overlap[:,0],X_overlap[:,1],c=y_overlap,cmap='bwr',edgecolors='k')

#Support Vectors
plt.scatter(
    svm_soft.support_vectors_[:,0],
    svm_soft.support_vectors_[:,1],
    s=120, facecolors='none', edgecolors='k', linewidth=2,
    label='Support Vectors'
)

#Decision boundry
x_vals=np.linspace(
    X_overlap[:,0].min()-1,
    X_overlap[:,0].max()+1,
    200
)

y_decision = -(w[0] * x_vals + b) / w[1]
y_margin_pos = -(w[0] * x_vals + b - 1) / w[1]
y_margin_neg = -(w[0] * x_vals + b +1 ) / w[1]

plt.plot(x_vals, y_decision, 'k-', label = "Decision Boundary")
plt.plot(x_vals, y_margin_pos, 'k--', label = "Margin +1")
plt.plot(x_vals, y_margin_neg, 'k--', label = "Margin -1")
 
# Shade margin area
plt.fill_between(
    x_vals, y_margin_pos, y_margin_neg,
    color='gray', alpha=0.2, label = "Margin Area"
)
 
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.title("Hard Margin SVM with Margin Visualization")
plt.legend()
plt.show()

# %% [markdown]
# Exercise

# %%
from sklearn .svm import SVC
svm_soft_eg=SVC(kernel='linear',C=0.1)
svm_soft_eg.fit(X_overlap,y_overlap)

print("Number of support vectors:", len(svm_soft_eg.support_vectors_))
# Out:
# Number of support vectors: 13

# %%
w=svm_soft_eg.coef_[0] 
b=svm_soft_eg.intercept_[0] 

plt.figure(figsize=(7,6))
plt.scatter(X_overlap[:,0],X_overlap[:,1],c=y_overlap,cmap='bwr',edgecolors='k')

#Support Vectors
plt.scatter(
    svm_soft_eg.support_vectors_[:,0],
    svm_soft_eg.support_vectors_[:,1],
    s=120, facecolors='none', edgecolors='k', linewidth=2,
    label='Support Vectors'
)

#Decision boundry
x_vals=np.linspace(
    X_overlap[:,0].min()-1,
    X_overlap[:,0].max()+1,
    200
)

y_decision = -(w[0] * x_vals + b) / w[1]
y_margin_pos = -(w[0] * x_vals + b - 1) / w[1]
y_margin_neg = -(w[0] * x_vals + b +1 ) / w[1]

plt.plot(x_vals, y_decision, 'k-', label = "Decision Boundary")
plt.plot(x_vals, y_margin_pos, 'k--', label = "Margin +1")
plt.plot(x_vals, y_margin_neg, 'k--', label = "Margin -1")
 
# Shade margin area
plt.fill_between(
    x_vals, y_margin_pos, y_margin_neg,
    color='gray', alpha=0.2, label = "Margin Area"
)
 
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.title("Hard Margin SVM with Margin Visualization")
plt.legend()
plt.show()

# %%
from sklearn .svm import SVC
svm_soft_eg1=SVC(kernel='linear',C=0.001)
svm_soft_eg1.fit(X_overlap,y_overlap)

print("Number of support vectors:", len(svm_soft_eg1.support_vectors_))
# Out:
# Number of support vectors: 60

# %%
w=svm_soft_eg1.coef_[0] 
b=svm_soft_eg1.intercept_[0] 

plt.figure(figsize=(7,6))
plt.scatter(X_overlap[:,0],X_overlap[:,1],c=y_overlap,cmap='bwr',edgecolors='k')

#Support Vectors
plt.scatter(
    svm_soft_eg1.support_vectors_[:,0],
    svm_soft_eg1.support_vectors_[:,1],
    s=120, facecolors='none', edgecolors='k', linewidth=2,
    label='Support Vectors'
)

#Decision boundry
x_vals=np.linspace(
    X_overlap[:,0].min()-1,
    X_overlap[:,0].max()+1,
    200
)

y_decision = -(w[0] * x_vals + b) / w[1]
y_margin_pos = -(w[0] * x_vals + b - 1) / w[1]
y_margin_neg = -(w[0] * x_vals + b +1 ) / w[1]

plt.plot(x_vals, y_decision, 'k-', label = "Decision Boundary")
plt.plot(x_vals, y_margin_pos, 'k--', label = "Margin +1")
plt.plot(x_vals, y_margin_neg, 'k--', label = "Margin -1")
 
# Shade margin area
plt.fill_between(
    x_vals, y_margin_pos, y_margin_neg,
    color='gray', alpha=0.2, label = "Margin Area"
)
 
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.title("Hard Margin SVM with Margin Visualization")
plt.legend()
plt.show()
